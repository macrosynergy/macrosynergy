# %%
import yaml
import numpy as np
import pandas as pd
from timeit import default_timer as timer
from datetime import timedelta, date

from macrosynergy.management.dq import DataQueryInterface

import os
print(f"Current working directory: {os.getcwd()}")
path_to_config = '..//data//'
# Out:
# Current working directory: /Users/kurransteeds/repos/macrosynergy

# %%
cids_dmca = ['AUD', 'CAD', 'CHF', 'EUR', 'GBP', 'JPY', 'NOK', 'NZD', 'SEK', 'USD']  # DM currency areas
cids_dmec = ['DEM', 'ESP', 'FRF', 'ITL', 'NLG']  # DM euro area countries
cids_latm = ['ARS', 'BRL', 'COP', 'CLP', 'MXN', 'PEN']  # Latam countries
cids_emea = ['HUF', 'ILS', 'PLN', 'RON', 'RUB', 'TRY', 'ZAR']  # EMEA countries
cids_emas = ['CNY', 'HKD', 'IDR', 'INR', 'KRW', 'MYR', 'PHP', 'SGD', 'THB', 'TWD']  # EM Asia countries
cids_dm = cids_dmca + cids_dmec
cids_em = cids_latm + cids_emea + cids_emas
cids = sorted(cids_dm + cids_em)

cids_eufx = ['CHF', 'HUF', 'NOK', 'PLN', 'RON', 'SEK']  # EUR benchmark
cids_g2fx = ['GBP', 'RUB', 'TRY']  # dual benchmark
cids_usfx = ['AUD', 'BRL', 'CAD', 'CLP', 'CNY', 'COP', 'EUR', 'IDR', 'ILS', 'INR', 'JPY', 'KRW', 'MYR',
             'MXN', 'NZD', 'PEN', 'PHP', 'SGD', 'THB', 'TWD', 'ZAR']  # USD benchmark
cids_fx = cids_usfx + cids_eufx + cids_g2fx

# %%
def dq_tickers(tickers, metrics=['value'], start_date = '2000-01-01'):
    
    """
    Returns standardized dataframe of specified base tickers and metric
    
    
    :param <List[str]> tickers: JPMaQS ticker of form <cid>_<xcat>.
    :param <List[str]> metrics: must choose one or more from 'value', 'eop_lag', 'mop_lag', or 'grade'. Default is ['value'].
    :param <str> start_date: first date in ISO 8601 string format. 
    :param <str> path: relative path from notebook to credential files.
    
    :return <pd.Dataframe> standardized dataframe with columns 'cid', 'xcats', 'real_date' and chosen metrics.
    """
    
    unique_tix = list(set(tickers))
    unique_tix.sort()
    dq_tix = []
    for metric in metrics:
        dq_tix = dq_tix + ["DB(JPMAQS," + tick + f",{metric})" for tick in unique_tix]
    
    with open("config.yml", 'r') as f:
        cf = yaml.load(f, Loader=yaml.FullLoader)

    with DataQueryInterface(
                username=cf["dq"]["username"],
                password=cf["dq"]["password"],
                crt="api_macrosynergy_com.crt",
                key="api_macrosynergy_com.key") as dq:
        
        print("Connected: ", dq.check_connection())
        df = dq.get_ts_expression(expression=dq_tix, original_metrics=metrics, start_date=start_date)
        
        if isinstance(df, pd.DataFrame):
            df = df.sort_values(['cid', 'xcat', 'real_date']).reset_index(drop=True)

    return df

# %%
def dq_download(tickers=None, xcats=None, cids=None, metrics=['value'], start_date = '2000-01-01', path = '..//data//'):
    
    """
    Returns standardized dataframe of specified base tickers and metrics
        
    :param <List[str]> tickers: JPMaQS ticker of form <cid>_<xcat>. Can be combined with selection of categories.
    :param <List[str]> xcats: JPMaQS category codes. Downloaded for all standard cross sections identifiers available 
    (if cids are not specified) or those selected (if cids are specified).
    Standard cross sections here include major developed and emerging currency markets. See JPMaQS documentation.
    :param <List[str]> cids: JPMaQS cross-section identifiers, typically based  on currency code. See JPMaQS documentation.
    :param <str> metrics: must choose one or more from 'value', 'eop_lag', 'mop_lag', or 'grade'. Default is ['value'].
    # Todo: allow multiple metrics to be downloaded
    :param <str> start_date: first date in ISO 8601 string format. 
    :param <str> path: relative path from notebook to credential files.
    
    :return <pd.Dataframe> standardized dataframe with columns 'cid', 'xcats', 'real_date' and chosen metrics.
    """
    
    # A. Collect all standard cross sections.
    
    if (cids is None) & (xcats is not None):
    
        cids_dmca = ['AUD', 'CAD', 'CHF', 'EUR', 'GBP', 'JPY', 'NOK', 'NZD', 'SEK', 'USD']  # DM currency areas
        cids_dmec = ['DEM', 'ESP', 'FRF', 'ITL', 'NLG']  # DM euro area countries
        cids_latm = ['BRL', 'COP', 'CLP', 'MXN', 'PEN']  # Latam countries
        cids_emea = ['HUF', 'ILS', 'PLN', 'RON', 'RUB', 'TRY', 'ZAR']  # EMEA countries
        cids_emas = ['CNY', 'IDR', 'INR', 'KRW', 'MYR', 'PHP', 'SGD', 'THB', 'TWD']  # EM Asia countries
        cids_dm = cids_dmca + cids_dmec
        cids_em = cids_latm + cids_emea + cids_emas
        cids = sorted(cids_dm + cids_em)  # standard default
        
    
    # B. Collect all tickers and metrics to be downloaded
    
    dl = {'tickers': tickers, 'xcats': xcats, 'cids': cids, 'metrics': metrics}
    for key, value in dl.items():
        if isinstance(value, str):
            exec(f"{key} = [{key}]")  # make sure all choices are iterables
        
    if tickers is None:
        tickers = []
    
    if xcats is not None:
        add_tix = [cid + '_' + xcat for xcat in xcats for cid in cids]
        tickers = tickers + add_tix
    
    df = pd.DataFrame(columns = ['cid', 'xcat', 'real_date', 'value'])
    df_add = dq_tickers(tickers, metrics=metrics, start_date = start_date)
    df.append(df_add)
        
    return df

# %%
cats = ['CPIXFE_SJA_P6M6ML6AR'] 
tix = [cid + '_' + cat for cid in cids for cat in cats]

start = timer()
df = dq_download(tickers=tix, metrics=['value'], xcats = 'DU05YXR_NSA', start_date='2021-11-01')  # import via API
end = timer()

print("Download time from DQ: "+ str(timedelta(seconds=end - start)))
print("Last updated:", date.today())
# Out:
# Connected:  True
# [{'item': 1, 'group': None, 'attributes': [{'expression': 'DB(JPMAQS,AUD_X,value)', 'label': None, 'attribute-id': None, 'attribute-name': None, 'time-series': [['20211101', None], ['20211102', None], ['20211103', None], ['20211104', None], ['20211105', None], ['20211106', None], ['20211107', None]]}], 'instrument-id': None, 'instrument-name': None}, {'item': 2, 'group': None, 'attributes': [{'expression': 'DB(JPMAQS,AUD_Y,value)', 'label': None, 'attribute-id': None, 'attribute-name': None, 'time-series': [['20211101', None], ['20211102', None], ['20211103', None], ['20211104', None], ['20211105', None], ['20211106', None], ['20211107', None]]}], 'instrument-id': None, 'instrument-name': None}, {'item': 3, 'group': None, 'attributes': [{'expression': 'DB(JPMAQS,AUD_CPIXFE_SJA_P6M6ML6AR,value)', 'label': None, 'attribute-id': None, 'attribute-name': None, 'time-series': [['20211101', 1.8135361606], ['20211102', 1.8135361606], ['20211103', 1.8135361606], ['20211104', None], ['20211105', None], ['20211106', None], ['20211107', None]]}], 'instrument-id': None, 'instrument-name': None}, {'item': 4, 'group': None, 'attributes': [{'expression': 'DB(JPMAQS,BRL_D,value)', 'label': None, 'attribute-id': None, 'attribute-name': None, 'time-series': [['20211101', None], ['20211102', None], ['20211103', None], ['20211104', None], ['20211105', None], ['20211106', None], ['20211107', None]]}], 'instrument-id': None, 'instrument-name': None}, {'item': 5, 'group': None, 'attributes': [{'expression': 'DB(JPMAQS,BRL_R,value)', 'label': None, 'attribute-id': None, 'attribute-name': None, 'time-series': [['20211101', None], ['20211102', None], ['20211103', None], ['20211104', None], ['20211105', None], ['20211106', None], ['20211107', None]]}], 'instrument-id': None, 'instrument-name': None}, {'item': 6, 'group': None, 'attributes': [{'expression': 'DB(JPMAQS,ARS_CPIXFE_SJA_P6M6ML6AR,value)', 'label': None, 'attribute-id': None, 'attribute-name': None, 'time-series': [['20211101', None], ['20211102', None], ['20211103', None], ['20211104', None], ['20211105', None], ['20211106', None], ['20211107', None]]}], 'instrument-id': None, 'instrument-name': None}, {'item': 7, 'group': None, 'attributes': [{'expression': 'DB(JPMAQS,AUD__,value)', 'label': None, 'attribute-id': None, 'attribute-name': None, 'time-series': [['20211101', None], ['20211102', None], ['20211103', None], ['20211104', None], ['20211105', None], ['20211106', None], ['20211107', None]]}], 'instrument-id': None, 'instrument-name': None}, {'item': 8, 'group': None, 'attributes': [{'expression': 'DB(JPMAQS,BRL_CPIXFE_SJA_P6M6ML6AR,value)', 'label': None, 'attribute-id': None, 'attribute-name': None, 'time-series': [['20211101', 4.594242859], ['20211102', 4.594242859], ['20211103', 4.594242859], ['20211104', None], ['20211105', None], ['20211106', None], ['20211107', None]]}], 'instrument-id': None, 'instrument-name': None}, {'item': 9, 'group': None, 'attributes': [{'expression': 'DB(JPMAQS,AUD_U,value)', 'label': None, 'attribute-id': None, 'attribute-name': None, 'time-series': [['20211101', None], ['20211102', None], ['20211103', None], ['20211104', None], ['20211105', None], ['20211106', None], ['20211107', None]]}], 'instrument-id': None, 'instrument-name': None}, {'item': 10, 'group': None, 'attributes': [{'expression': 'DB(JPMAQS,BRL_A,value)', 'label': None, 'attribute-id': None, 'attribute-name': None, 'time-series': [['20211101', None], ['20211102', None], ['20211103', None], ['20211104', None], ['20211105', None], ['20211106', None], ['20211107', None]]}], 'instrument-id': None, 'instrument-name': None}, {'item': 11, 'group': None, 'attributes': [{'expression': 'DB(JPMAQS,AUD_0,value)', 'label': None, 'attribute-id': None, 'attribute-name': None, 'time-series': [['20211101', None], ['20211102', None], ['20211103', None], ['20211104', None], ['20211105', None], ['20211106', None], ['20211107', None]]}], 'instrument-id': None, 'instrument-name': None}, {'item': 12, 'group': N ...
# The ticker, DB(JPMAQS,ZAR_0, does not exist in the Database.
# The ticker, DB(JPMAQS,ZAR_5, does not exist in the Database.
# The ticker, DB(JPMAQS,ZAR_A, does not exist in the Database.
# The ticker, DB(JPMAQS,ZAR__, does not exist in the Database.
# The ticker, DB(JPMAQS,ZAR_R, does not exist in the Database.
# The ticker, DB(JPMAQS,ZAR_U, does not exist in the Database.
# The ticker, DB(JPMAQS,ZAR_D, does not exist in the Database.
# The ticker, DB(JPMAQS,USD_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,ZAR_S, does not exist in the Database.
# The ticker, DB(JPMAQS,ZAR_X, does not exist in the Database.
# The ticker, DB(JPMAQS,USD__, does not exist in the Database.
# The ticker, DB(JPMAQS,ZAR_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,ZAR_N, does not exist in the Database.
# The ticker, DB(JPMAQS,USD_A, does not exist in the Database.
# The ticker, DB(JPMAQS,USD_D, does not exist in the Database.
# The ticker, DB(JPMAQS,USD_U, does not exist in the Database.
# The ticker, DB(JPMAQS,USD_0, does not exist in the Database.
# The ticker, DB(JPMAQS,TWD_A, does not exist in the Database.
# The ticker, DB(JPMAQS,USD_N, does not exist in the Database.
# The ticker, DB(JPMAQS,TWD_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,TWD_N, does not exist in the Database.
# The ticker, DB(JPMAQS,USD_X, does not exist in the Database.
# The ticker, DB(JPMAQS,TWD__, does not exist in the Database.
# The ticker, DB(JPMAQS,TWD_X, does not exist in the Database.
# The ticker, DB(JPMAQS,TWD_D, does not exist in the Database.
# The ticker, DB(JPMAQS,TWD_U, does not exist in the Database.
# The ticker, DB(JPMAQS,TWD_R, does not exist in the Database.
# The ticker, DB(JPMAQS,USD_S, does not exist in the Database.
# The ticker, DB(JPMAQS,USD_5, does not exist in the Database.
# The ticker, DB(JPMAQS,TWD_S, does not exist in the Database.
# The ticker, DB(JPMAQS,USD_R, does not exist in the Database.
# The ticker, DB(JPMAQS,TRY__, does not exist in the Database.
# The ticker, DB(JPMAQS,TRY_X, does not exist in the Database.
# The ticker, DB(JPMAQS,TRY_R, does not exist in the Database.
# The ticker, DB(JPMAQS,TRY_N, does not exist in the Database.
# The ticker, DB(JPMAQS,TRY_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,TRY_U, does not exist in the Database.
# The ticker, DB(JPMAQS,TRY_D, does not exist in the Database.
# The ticker, DB(JPMAQS,THB_U, does not exist in the Database.
# The ticker, DB(JPMAQS,TRY_S, does not exist in the Database.
# The ticker, DB(JPMAQS,THB__, does not exist in the Database.
# The ticker, DB(JPMAQS,TWD_0, does not exist in the Database.
# The ticker, DB(JPMAQS,THB_S, does not exist in the Database.
# The ticker, DB(JPMAQS,THB_R, does not exist in the Database.
# The ticker, DB(JPMAQS,TRY_0, does not exist in the Database.
# The ticker, DB(JPMAQS,TRY_5, does not exist in the Database.
# The ticker, DB(JPMAQS,TWD_5, does not exist in the Database.
# The ticker, DB(JPMAQS,THB_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,THB_X, does not exist in the Database.
# The ticker, DB(JPMAQS,TRY_A, does not exist in the Database.
# The ticker, DB(JPMAQS,THB_A, does not exist in the Database.
# The ticker, DB(JPMAQS,SGD__, does not exist in the Database.
# The ticker, DB(JPMAQS,THB_D, does not exist in the Database.
# The ticker, DB(JPMAQS,SGD_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,SGD_U, does not exist in the Database.
# The ticker, DB(JPMAQS,SGD_X, does not exist in the Database.
# The ticker, DB(JPMAQS,THB_0, does not exist in the Database.
# The ticker, DB(JPMAQS,SGD_N, does not exist in the Database.
# The ticker, DB(JPMAQS,SGD_A, does not exist in the Database.
# The ticker, DB(JPMAQS,THB_N, does not exist in the Database.
# The ticker, DB(JPMAQS,THB_5, does not exist in the Database.
# The ticker, DB(JPMAQS,SGD_S, does not exist in the Database.
# The ticker, DB(JPMAQS,SGD_R, does not exist in the Database.
# The ticker, DB(JPMAQS,SGD_D, does not exist in the Database.
# The ticker, DB(JPMAQS,SGD_5, does not exist in the Database.
# The ticker, DB(JPMAQS,SEK__, does not exist in the Database.
# The ticker, DB(JPMAQS,SGD_0, does not exist in the Database.
# The ticker, DB(JPMAQS,SEK_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,SEK_5, does not exist in the Database.
# The ticker, DB(JPMAQS,RUB_A, does not exist in the Database.
# The ticker, DB(JPMAQS,SEK_A, does not exist in the Database.
# The ticker, DB(JPMAQS,SEK_S, does not exist in the Database.
# The ticker, DB(JPMAQS,SEK_D, does not exist in the Database.
# The ticker, DB(JPMAQS,RUB_N, does not exist in the Database.
# The ticker, DB(JPMAQS,SEK_R, does not exist in the Database.
# The ticker, DB(JPMAQS,SEK_X, does not exist in the Database.
# The ticker, DB(JPMAQS,RUB_R, does not exist in the Database.
# The ticker, DB(JPMAQS,RUB_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,SEK_U, does not exist in the Database.
# The ticker, DB(JPMAQS,RUB__, does not exist in the Database.
# The ticker, DB(JPMAQS,SEK_N, does not exist in the Database.
# The ticker, DB(JPMAQS,RUB_X, does not exist in the Database.
# The ticker, DB(JPMAQS,SEK_0, does not exist in the Database.
# The ticker, DB(JPMAQS,RUB_D, does not exist in the Database.
# The ticker, DB(JPMAQS,RUB_U, does not exist in the Database.
# The ticker, DB(JPMAQS,RUB_S, does not exist in the Database.
# The ticker, DB(JPMAQS,PLN__, does not exist in the Database.
# The ticker, DB(JPMAQS,PLN_S, does not exist in the Database.
# The ticker, DB(JPMAQS,PLN_U, does not exist in the Database.
# The ticker, DB(JPMAQS,PLN_R, does not exist in the Database.
# The ticker, DB(JPMAQS,RUB_0, does not exist in the Database.
# The ticker, DB(JPMAQS,RON_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,RON_X, does not exist in the Database.
# The ticker, DB(JPMAQS,RON__, does not exist in the Database.
# The ticker, DB(JPMAQS,RON_R, does not exist in the Database.
# The ticker, DB(JPMAQS,RON_S, does not exist in the Database.
# The ticker, DB(JPMAQS,RON_D, does not exist in the Database.
# The ticker, DB(JPMAQS,RON_N, does not exist in the Database.
# The ticker, DB(JPMAQS,RON_U, does not exist in the Database.
# The ticker, DB(JPMAQS,RON_0, does not exist in the Database.
# The ticker, DB(JPMAQS,RON_5, does not exist in the Database.
# The ticker, DB(JPMAQS,RUB_5, does not exist in the Database.
# The ticker, DB(JPMAQS,RON_A, does not exist in the Database.
# The ticker, DB(JPMAQS,PLN_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,PLN_X, does not exist in the Database.
# The ticker, DB(JPMAQS,PLN_N, does not exist in the Database.
# The ticker, DB(JPMAQS,PLN_5, does not exist in the Database.
# The ticker, DB(JPMAQS,PLN_D, does not exist in the Database.
# The ticker, DB(JPMAQS,PLN_A, does not exist in the Database.
# The ticker, DB(JPMAQS,PHP__, does not exist in the Database.
# The ticker, DB(JPMAQS,PEN__, does not exist in the Database.
# The ticker, DB(JPMAQS,PHP_A, does not exist in the Database.
# The ticker, DB(JPMAQS,PHP_N, does not exist in the Database.
# The ticker, DB(JPMAQS,PHP_0, does not exist in the Database.
# The ticker, DB(JPMAQS,PHP_D, does not exist in the Database.
# The ticker, DB(JPMAQS,PHP_5, does not exist in the Database.
# The ticker, DB(JPMAQS,PEN_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,PLN_0, does not exist in the Database.
# The ticker, DB(JPMAQS,PHP_R, does not exist in the Database.
# The ticker, DB(JPMAQS,PHP_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,PHP_X, does not exist in the Database.
# The ticker, DB(JPMAQS,PHP_U, does not exist in the Database.
# The ticker, DB(JPMAQS,PHP_S, does not exist in the Database.
# The ticker, DB(JPMAQS,NZD__, does not exist in the Database.
# The ticker, DB(JPMAQS,PEN_N, does not exist in the Database.
# The ticker, DB(JPMAQS,NZD_A, does not exist in the Database.
# The ticker, DB(JPMAQS,NZD_N, does not exist in the Database.
# The ticker, DB(JPMAQS,PEN_5, does not exist in the Database.
# The ticker, DB(JPMAQS,PEN_0, does not exist in the Database.
# The ticker, DB(JPMAQS,PEN_A, does not exist in the Database.
# The ticker, DB(JPMAQS,NZD_D, does not exist in the Database.
# The ticker, DB(JPMAQS,PEN_S, does not exist in the Database.
# The ticker, DB(JPMAQS,PEN_D, does not exist in the Database.
# The ticker, DB(JPMAQS,PEN_R, does not exist in the Database.
# The ticker, DB(JPMAQS,NZD_R, does not exist in the Database.
# The ticker, DB(JPMAQS,NZD_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,NZD_X, does not exist in the Database.
# The ticker, DB(JPMAQS,NZD_U, does not exist in the Database.
# The ticker, DB(JPMAQS,NZD_S, does not exist in the Database.
# The ticker, DB(JPMAQS,PEN_X, does not exist in the Database.
# The ticker, DB(JPMAQS,PEN_U, does not exist in the Database.
# The ticker, DB(JPMAQS,NLG_S, does not exist in the Database.
# The ticker, DB(JPMAQS,NLG_R, does not exist in the Database.
# The ticker, DB(JPMAQS,NLG_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,NLG_U, does not exist in the Database.
# The ticker, DB(JPMAQS,NOK__, does not exist in the Database.
# The ticker, DB(JPMAQS,NOK_0, does not exist in the Database.
# The ticker, DB(JPMAQS,NOK_N, does not exist in the Database.
# The ticker, DB(JPMAQS,NLG_X, does not exist in the Database.
# The ticker, DB(JPMAQS,NOK_A, does not exist in the Database.
# The ticker, DB(JPMAQS,NZD_0, does not exist in the Database.
# The ticker, DB(JPMAQS,NOK_D, does not exist in the Database.
# The ticker, DB(JPMAQS,NOK_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,NOK_X, does not exist in the Database.
# The ticker, DB(JPMAQS,NOK_S, does not exist in the Database.
# The ticker, DB(JPMAQS,NZD_5, does not exist in the Database.
# The ticker, DB(JPMAQS,NOK_5, does not exist in the Database.
# The ticker, DB(JPMAQS,NOK_R, does not exist in the Database.
# The ticker, DB(JPMAQS,NOK_U, does not exist in the Database.
# The ticker, DB(JPMAQS,NLG__, does not exist in the Database.
# The ticker, DB(JPMAQS,NLG_N, does not exist in the Database.
# The ticker, DB(JPMAQS,NLG_D, does not exist in the Database.
# The ticker, DB(JPMAQS,NLG_0, does not exist in the Database.
# The ticker, DB(JPMAQS,MYR_S, does not exist in the Database.
# The ticker, DB(JPMAQS,MYR_R, does not exist in the Database.
# The ticker, DB(JPMAQS,MYR_N, does not exist in the Database.
# The ticker, DB(JPMAQS,NLG_CPIXFE_SJA_P6M6ML6AR, does not exist in the Database.
# The ticker, DB(JPMAQS,MYR_A, does not exist in the Database.
# The ticker, DB(JPMAQS,MYR__, does not exist in the Database.
# The ticker, DB(JPMAQS,MXN_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,MYR_0, does not exist in the Database.
# The ticker, DB(JPMAQS,MXN__, does not exist in the Database.
# The ticker, DB(JPMAQS,MYR_5, does not exist in the Database.
# The ticker, DB(JPMAQS,MYR_D, does not exist in the Database.
# The ticker, DB(JPMAQS,MYR_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,MYR_X, does not exist in the Database.
# The ticker, DB(JPMAQS,MYR_U, does not exist in the Database.
# The ticker, DB(JPMAQS,NLG_5, does not exist in the Database.
# The ticker, DB(JPMAQS,NLG_A, does not exist in the Database.
# The ticker, DB(JPMAQS,KRW_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,KRW_U, does not exist in the Database.
# The ticker, DB(JPMAQS,KRW_S, does not exist in the Database.
# The ticker, DB(JPMAQS,KRW_R, does not exist in the Database.
# The ticker, DB(JPMAQS,KRW_X, does not exist in the Database.
# The ticker, DB(JPMAQS,MXN_X, does not exist in the Database.
# The ticker, DB(JPMAQS,MXN_U, does not exist in the Database.
# The ticker, DB(JPMAQS,MXN_R, does not exist in the Database.
# The ticker, DB(JPMAQS,MXN_N, does not exist in the Database.
# The ticker, DB(JPMAQS,KRW_D, does not exist in the Database.
# The ticker, DB(JPMAQS,MXN_5, does not exist in the Database.
# The ticker, DB(JPMAQS,MXN_S, does not exist in the Database.
# The ticker, DB(JPMAQS,MXN_D, does not exist in the Database.
# The ticker, DB(JPMAQS,KRW__, does not exist in the Database.
# The ticker, DB(JPMAQS,MXN_0, does not exist in the Database.
# The ticker, DB(JPMAQS,KRW_A, does not exist in the Database.
# The ticker, DB(JPMAQS,MXN_A, does not exist in the Database.
# The ticker, DB(JPMAQS,KRW_N, does not exist in the Database.
# The ticker, DB(JPMAQS,ITL_S, does not exist in the Database.
# The ticker, DB(JPMAQS,JPY_0, does not exist in the Database.
# The ticker, DB(JPMAQS,ITL_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,ITL_R, does not exist in the Database.
# The ticker, DB(JPMAQS,ITL__, does not exist in the Database.
# The ticker, DB(JPMAQS,JPY_X, does not exist in the Database.
# The ticker, DB(JPMAQS,JPY_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,JPY_N, does not exist in the Database.
# The ticker, DB(JPMAQS,JPY_U, does not exist in the Database.
# The ticker, DB(JPMAQS,JPY_S, does not exist in the Database.
# The ticker, DB(JPMAQS,KRW_5, does not exist in the Database.
# The ticker, DB(JPMAQS,JPY_A, does not exist in the Database.
# The ticker, DB(JPMAQS,JPY_D, does not exist in the Database.
# The ticker, DB(JPMAQS,ITL_X, does not exist in the Database.
# The ticker, DB(JPMAQS,JPY_5, does not exist in the Database.
# The ticker, DB(JPMAQS,JPY_R, does not exist in the Database.
# The ticker, DB(JPMAQS,ITL_U, does not exist in the Database.
# The ticker, DB(JPMAQS,KRW_0, does not exist in the Database.
# The ticker, DB(JPMAQS,JPY__, does not exist in the Database.
# The ticker, DB(JPMAQS,ITL_5, does not exist in the Database.
# The ticker, DB(JPMAQS,ITL_0, does not exist in the Database.
# The ticker, DB(JPMAQS,ITL_A, does not exist in the Database.
# The ticker, DB(JPMAQS,ITL_D, does not exist in the Database.
# The ticker, DB(JPMAQS,INR_X, does not exist in the Database.
# The ticker, DB(JPMAQS,ITL_N, does not exist in the Database.
# The ticker, DB(JPMAQS,ILS_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,INR_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,INR_5, does not exist in the Database.
# The ticker, DB(JPMAQS,INR_0, does not exist in the Database.
# The ticker, DB(JPMAQS,INR_A, does not exist in the Database.
# The ticker, DB(JPMAQS,INR_U, does not exist in the Database.
# The ticker, DB(JPMAQS,INR_N, does not exist in the Database.
# The ticker, DB(JPMAQS,INR__, does not exist in the Database.
# The ticker, DB(JPMAQS,ITL_CPIXFE_SJA_P6M6ML6AR, does not exist in the Database.
# The ticker, DB(JPMAQS,INR_S, does not exist in the Database.
# The ticker, DB(JPMAQS,INR_D, does not exist in the Database.
# The ticker, DB(JPMAQS,INR_R, does not exist in the Database.
# The ticker, DB(JPMAQS,ILS__, does not exist in the Database.
# The ticker, DB(JPMAQS,IDR_R, does not exist in the Database.
# The ticker, DB(JPMAQS,IDR_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,IDR__, does not exist in the Database.
# The ticker, DB(JPMAQS,IDR_X, does not exist in the Database.
# The ticker, DB(JPMAQS,IDR_A, does not exist in the Database.
# The ticker, DB(JPMAQS,IDR_N, does not exist in the Database.
# The ticker, DB(JPMAQS,ILS_X, does not exist in the Database.
# The ticker, DB(JPMAQS,ILS_D, does not exist in the Database.
# The ticker, DB(JPMAQS,ILS_A, does not exist in the Database.
# The ticker, DB(JPMAQS,ILS_S, does not exist in the Database.
# The ticker, DB(JPMAQS,ILS_R, does not exist in the Database.
# The ticker, DB(JPMAQS,ILS_N, does not exist in the Database.
# The ticker, DB(JPMAQS,ILS_5, does not exist in the Database.
# The ticker, DB(JPMAQS,ILS_0, does not exist in the Database.
# The ticker, DB(JPMAQS,ILS_U, does not exist in the Database.
# The ticker, DB(JPMAQS,IDR_D, does not exist in the Database.
# The ticker, DB(JPMAQS,IDR_S, does not exist in the Database.
# The ticker, DB(JPMAQS,IDR_U, does not exist in the Database.
# The ticker, DB(JPMAQS,GBP_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,GBP_X, does not exist in the Database.
# The ticker, DB(JPMAQS,GBP__, does not exist in the Database.
# The ticker, DB(JPMAQS,HUF_5, does not exist in the Database.
# The ticker, DB(JPMAQS,GBP_S, does not exist in the Database.
# The ticker, DB(JPMAQS,HUF_A, does not exist in the Database.
# The ticker, DB(JPMAQS,HUF_X, does not exist in the Database.
# The ticker, DB(JPMAQS,HUF_U, does not exist in the Database.
# The ticker, DB(JPMAQS,HUF_R, does not exist in the Database.
# The ticker, DB(JPMAQS,HUF_S, does not exist in the Database.
# The ticker, DB(JPMAQS,HUF_D, does not exist in the Database.
# The ticker, DB(JPMAQS,IDR_0, does not exist in the Database.
# The ticker, DB(JPMAQS,HKD_CPIXFE_SJA_P6M6ML6AR, does not exist in the Database.
# The ticker, DB(JPMAQS,HUF_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,HUF__, does not exist in the Database.
# The ticker, DB(JPMAQS,IDR_5, does not exist in the Database.
# The ticker, DB(JPMAQS,HUF_N, does not exist in the Database.
# The ticker, DB(JPMAQS,HUF_0, does not exist in the Database.
# The ticker, DB(JPMAQS,GBP_U, does not exist in the Database.
# The ticker, DB(JPMAQS,GBP_R, does not exist in the Database.
# The ticker, DB(JPMAQS,EUR__, does not exist in the Database.
# The ticker, DB(JPMAQS,GBP_D, does not exist in the Database.
# The ticker, DB(JPMAQS,GBP_A, does not exist in the Database.
# The ticker, DB(JPMAQS,FRF__, does not exist in the Database.
# The ticker, DB(JPMAQS,FRF_N, does not exist in the Database.
# The ticker, DB(JPMAQS,GBP_N, does not exist in the Database.
# The ticker, DB(JPMAQS,GBP_0, does not exist in the Database.
# The ticker, DB(JPMAQS,FRF_0, does not exist in the Database.
# The ticker, DB(JPMAQS,FRF_5, does not exist in the Database.
# The ticker, DB(JPMAQS,FRF_D, does not exist in the Database.
# The ticker, DB(JPMAQS,FRF_A, does not exist in the Database.
# The ticker, DB(JPMAQS,FRF_R, does not exist in the Database.
# The ticker, DB(JPMAQS,FRF_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,FRF_X, does not exist in the Database.
# The ticker, DB(JPMAQS,FRF_CPIXFE_SJA_P6M6ML6AR, does not exist in the Database.
# The ticker, DB(JPMAQS,GBP_5, does not exist in the Database.
# The ticker, DB(JPMAQS,FRF_S, does not exist in the Database.
# The ticker, DB(JPMAQS,FRF_U, does not exist in the Database.
# The ticker, DB(JPMAQS,ESP_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,ESP_U, does not exist in the Database.
# The ticker, DB(JPMAQS,ESP_S, does not exist in the Database.
# The ticker, DB(JPMAQS,ESP_R, does not exist in the Database.
# The ticker, DB(JPMAQS,ESP_N, does not exist in the Database.
# The ticker, DB(JPMAQS,ESP_D, does not exist in the Database.
# The ticker, DB(JPMAQS,EUR_U, does not exist in the Database.
# The ticker, DB(JPMAQS,EUR_N, does not exist in the Database.
# The ticker, DB(JPMAQS,EUR_D, does not exist in the Database.
# The ticker, DB(JPMAQS,EUR_A, does not exist in the Database.
# The ticker, DB(JPMAQS,ESP_CPIXFE_SJA_P6M6ML6AR, does not exist in the Database.
# The ticker, DB(JPMAQS,EUR_S, does not exist in the Database.
# The ticker, DB(JPMAQS,EUR_R, does not exist in the Database.
# The ticker, DB(JPMAQS,EUR_5, does not exist in the Database.
# The ticker, DB(JPMAQS,ESP__, does not exist in the Database.
# The ticker, DB(JPMAQS,EUR_0, does not exist in the Database.
# The ticker, DB(JPMAQS,EUR_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,EUR_X, does not exist in the Database.
# The ticker, DB(JPMAQS,ESP_X, does not exist in the Database.
# The ticker, DB(JPMAQS,DEM_5, does not exist in the Database.
# The ticker, DB(JPMAQS,DEM_0, does not exist in the Database.
# The ticker, DB(JPMAQS,DEM_N, does not exist in the Database.
# The ticker, DB(JPMAQS,DEM_A, does not exist in the Database.
# The ticker, DB(JPMAQS,ESP_0, does not exist in the Database.
# The ticker, DB(JPMAQS,DEM__, does not exist in the Database.
# The ticker, DB(JPMAQS,COP_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,ESP_5, does not exist in the Database.
# The ticker, DB(JPMAQS,DEM_U, does not exist in the Database.
# The ticker, DB(JPMAQS,COP_X, does not exist in the Database.
# The ticker, DB(JPMAQS,DEM_R, does not exist in the Database.
# The ticker, DB(JPMAQS,ESP_A, does not exist in the Database.
# The ticker, DB(JPMAQS,DEM_D, does not exist in the Database.
# The ticker, DB(JPMAQS,DEM_S, does not exist in the Database.
# The ticker, DB(JPMAQS,COP__, does not exist in the Database.
# The ticker, DB(JPMAQS,COP_U, does not exist in the Database.
# The ticker, DB(JPMAQS,DEM_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,DEM_X, does not exist in the Database.
# The ticker, DB(JPMAQS,DEM_CPIXFE_SJA_P6M6ML6AR, does not exist in the Database.
# The ticker, DB(JPMAQS,COP_S, does not exist in the Database.
# The ticker, DB(JPMAQS,COP_0, does not exist in the Database.
# The ticker, DB(JPMAQS,COP_N, does not exist in the Database.
# The ticker, DB(JPMAQS,COP_A, does not exist in the Database.
# The ticker, DB(JPMAQS,CNY_A, does not exist in the Database.
# The ticker, DB(JPMAQS,CNY_N, does not exist in the Database.
# The ticker, DB(JPMAQS,CNY_0, does not exist in the Database.
# The ticker, DB(JPMAQS,CLP__, does not exist in the Database.
# The ticker, DB(JPMAQS,CNY__, does not exist in the Database.
# The ticker, DB(JPMAQS,CNY_S, does not exist in the Database.
# The ticker, DB(JPMAQS,CNY_R, does not exist in the Database.
# The ticker, DB(JPMAQS,CNY_X, does not exist in the Database.
# The ticker, DB(JPMAQS,CNY_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,CNY_5, does not exist in the Database.
# The ticker, DB(JPMAQS,CNY_D, does not exist in the Database.
# The ticker, DB(JPMAQS,COP_D, does not exist in the Database.
# The ticker, DB(JPMAQS,COP_R, does not exist in the Database.
# The ticker, DB(JPMAQS,COP_5, does not exist in the Database.
# The ticker, DB(JPMAQS,CNY_U, does not exist in the Database.
# The ticker, DB(JPMAQS,CLP_R, does not exist in the Database.
# The ticker, DB(JPMAQS,CHF_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,CHF_N, does not exist in the Database.
# The ticker, DB(JPMAQS,CLP_A, does not exist in the Database.
# The ticker, DB(JPMAQS,CLP_5, does not exist in the Database.
# The ticker, DB(JPMAQS,CLP_CPIXFE_SJA_P6M6ML6AR, does not exist in the Database.
# The ticker, DB(JPMAQS,CLP_0, does not exist in the Database.
# The ticker, DB(JPMAQS,CLP_N, does not exist in the Database.
# The ticker, DB(JPMAQS,CHF__, does not exist in the Database.
# The ticker, DB(JPMAQS,CLP_S, does not exist in the Database.
# The ticker, DB(JPMAQS,CLP_D, does not exist in the Database.
# The ticker, DB(JPMAQS,CHF_X, does not exist in the Database.
# The ticker, DB(JPMAQS,CHF_D, does not exist in the Database.
# The ticker, DB(JPMAQS,CLP_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,CLP_U, does not exist in the Database.
# The ticker, DB(JPMAQS,CHF_U, does not exist in the Database.
# The ticker, DB(JPMAQS,CHF_R, does not exist in the Database.
# The ticker, DB(JPMAQS,CLP_X, does not exist in the Database.
# The ticker, DB(JPMAQS,CHF_S, does not exist in the Database.
# The ticker, DB(JPMAQS,CHF_A, does not exist in the Database.
# The ticker, DB(JPMAQS,BRL__, does not exist in the Database.
# The ticker, DB(JPMAQS,BRL_U, does not exist in the Database.
# The ticker, DB(JPMAQS,CHF_0, does not exist in the Database.
# The ticker, DB(JPMAQS,CAD_5, does not exist in the Database.
# The ticker, DB(JPMAQS,CAD_S, does not exist in the Database.
# The ticker, DB(JPMAQS,CAD_D, does not exist in the Database.
# The ticker, DB(JPMAQS,BRL_S, does not exist in the Database.
# The ticker, DB(JPMAQS,CAD_N, does not exist in the Database.
# The ticker, DB(JPMAQS,CAD_R, does not exist in the Database.
# The ticker, DB(JPMAQS,CAD_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,CAD_X, does not exist in the Database.
# The ticker, DB(JPMAQS,CAD_U, does not exist in the Database.
# The ticker, DB(JPMAQS,CAD__, does not exist in the Database.
# The ticker, DB(JPMAQS,CAD_A, does not exist in the Database.
# The ticker, DB(JPMAQS,BRL_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,BRL_X, does not exist in the Database.
# The ticker, DB(JPMAQS,CAD_0, does not exist in the Database.
# The ticker, DB(JPMAQS,CHF_5, does not exist in the Database.
# The ticker, DB(JPMAQS,BRL_5, does not exist in the Database.
# The ticker, DB(JPMAQS,AUD_N, does not exist in the Database.
# The ticker, DB(JPMAQS,AUD_A, does not exist in the Database.
# The ticker, DB(JPMAQS,AUD_S, does not exist in the Database.
# The ticker, DB(JPMAQS,AUD_R, does not exist in the Database.
# The ticker, DB(JPMAQS,BRL_0, does not exist in the Database.
# The ticker, DB(JPMAQS,AUD_D, does not exist in the Database.
# The ticker, DB(JPMAQS,AUD_5, does not exist in the Database.
# The ticker, DB(JPMAQS,BRL_N, does not exist in the Database.
# The ticker, DB(JPMAQS,AUD_0, does not exist in the Database.
# The ticker, DB(JPMAQS,BRL_A, does not exist in the Database.
# The ticker, DB(JPMAQS,AUD_U, does not exist in the Database.
# The ticker, DB(JPMAQS,AUD__, does not exist in the Database.
# The ticker, DB(JPMAQS,ARS_CPIXFE_SJA_P6M6ML6AR, does not exist in the Database.
# The ticker, DB(JPMAQS,BRL_R, does not exist in the Database.
# The ticker, DB(JPMAQS,BRL_D, does not exist in the Database.
# The ticker, DB(JPMAQS,AUD_Y, does not exist in the Database.
# The ticker, DB(JPMAQS,AUD_X, does not exist in the Database.
# Download time from DQ: 0:02:58.072258
# Last updated: 2021-11-08

# %%
print(df.shape)
print(df.head())
print(df['cid'].unique())
print(df['xcat'].unique())
# Out:
# (56980, 4)
#    cid                       xcat  real_date     value
# 0  AUD  INTRGDP_NSA_P1M1ML12_3MMA 2000-01-03  4.221025
# 1  AUD  INTRGDP_NSA_P1M1ML12_3MMA 2000-01-04  4.221025
# 2  AUD  INTRGDP_NSA_P1M1ML12_3MMA 2000-01-05  4.221025
# 3  AUD  INTRGDP_NSA_P1M1ML12_3MMA 2000-01-06  4.221025
# 4  AUD  INTRGDP_NSA_P1M1ML12_3MMA 2000-01-07  4.221025
# ['AUD' 'CAD' 'CHF' 'EUR' 'GBP' 'JPY' 'NOK' 'NZD' 'SEK' 'USD']
# ['INTRGDP_NSA_P1M1ML12_3MMA']
